# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 601

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "metric"
baseURL = f"{url}appid={weather_api_key}&units={units}&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{baseURL}{city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ulladulla
# Processing Record 2 of Set 1 | bethel
# Processing Record 3 of Set 1 | ust-nera
# Processing Record 4 of Set 1 | ilulissat
# Processing Record 5 of Set 1 | grytviken
# Processing Record 6 of Set 1 | san antonio de pale
# Processing Record 7 of Set 1 | hakui
# Processing Record 8 of Set 1 | saipan
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | dudinka
# Processing Record 11 of Set 1 | ribeira grande
# Processing Record 12 of Set 1 | adamstown
# Processing Record 13 of Set 1 | aasiaat
# Processing Record 14 of Set 1 | port-aux-francais
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | zakynthos
# Processing Record 17 of Set 1 | longyearbyen
# Processing Record 18 of Set 1 | udachny
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | qaqortoq
# Processing Record 21 of Set 1 | popondetta
# Processing Record 22 of Set 1 | akureyri
# Processing Record 23 of Set 1 | sant antoni de portmany
# Processing Record 24 of Set 1 | piti village
# Processing Record 25 of Set 1 | maintirano
# Processing Record 26 of Set 1 | inhambane
# Processing Record 27 of Set 1 | nantucket
# Processing Record 28 of Set 1 | kirakira
# Processing Record 29 of Set 1 | badger
# Processing Record 30 of Set 1 | san jose
# Processing Record 31 of Set 1 | myitkyina
# Processing Record 32 of Set 1 | angra do heroismo
# Processing Record 33 of Set 1 | langfang
# Processing Record 34 of Set 1 | lompoc
# Processing Record 35 of Set 1 | iqaluit
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | konarka
# Processing Record 38 of Set 1 | tiksi
# Processing Record 39 of Set 1 | markovo
# Processing Record 40 of Set 1 | kushiro
# Processing Record 41 of Set 1 | isafjordur
# Processing Record 42 of Set 1 | broome
# Processing Record 43 of Set 1 | colonia
# Processing Record 44 of Set 1 | bilibino
# Processing Record 45 of Set 1 | latehar
# Processing Record 46 of Set 1 | lockwood
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | ungheni
# Processing Record 49 of Set 1 | smithers
# Processing Record 50 of Set 1 | kavieng
# Processing Record 0 of Set 2 | saint augustine beach
# Processing Record 1 of Set 2 | moussoro
# Processing Record 2 of Set 2 | khark
# Processing Record 3 of Set 2 | kokstad
# Processing Record 4 of Set 2 | ak'ordat
# Processing Record 5 of Set 2 | nar'yan-mar
# Processing Record 6 of Set 2 | hami
# Processing Record 7 of Set 2 | tazovsky
# Processing Record 8 of Set 2 | bratslav
# Processing Record 9 of Set 2 | waitangi
# Processing Record 10 of Set 2 | alesund
# Processing Record 11 of Set 2 | yellowknife
# Processing Record 12 of Set 2 | zelenokumsk
# Processing Record 13 of Set 2 | navia
# Processing Record 14 of Set 2 | invercargill
# Processing Record 15 of Set 2 | jilma
# Processing Record 16 of Set 2 | vadso
# Processing Record 17 of Set 2 | seeb
# Processing Record 18 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 19 of Set 2 | olonkinbyen
# Processing Record 20 of Set 2 | bacsalmas
# Processing Record 21 of Set 2 | abepura
# Processing Record 22 of Set 2 | kataragama
# City not found. Skipping...
# Processing Record 23 of Set 2 | enewetak
# Processing Record 24 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 25 of Set 2 | gadzhiyevo
# Processing Record 26 of Set 2 | armacao de buzios
# Processing Record 27 of Set 2 | edinburgh of the seven seas
# Processing Record 28 of Set 2 | casale monferrato
# Processing Record 29 of Set 2 | borogontsy
# Processing Record 30 of Set 2 | puerto natales
# Processing Record 31 of Set 2 | grand falls-windsor
# Processing Record 32 of Set 2 | sanctuary point
# Processing Record 33 of Set 2 | alofi
# Processing Record 34 of Set 2 | vilyuchinsk
# Processing Record 35 of Set 2 | ain sefra
# Processing Record 36 of Set 2 | keflavik
# Processing Record 37 of Set 2 | vila do maio
# Processing Record 38 of Set 2 | puerto ayora
# Processing Record 39 of Set 2 | richards bay
# Processing Record 40 of Set 2 | priob'ye
# Processing Record 41 of Set 2 | arraial do cabo
# Processing Record 42 of Set 2 | wailua homesteads
# Processing Record 43 of Set 2 | kaedi
# Processing Record 44 of Set 2 | lerwick
# Processing Record 45 of Set 2 | acarau
# Processing Record 46 of Set 2 | ancud
# Processing Record 47 of Set 2 | blackmans bay
# Processing Record 48 of Set 2 | vorgashor
# Processing Record 49 of Set 2 | bahia blanca
# Processing Record 0 of Set 3 | college
# Processing Record 1 of Set 3 | ouadda
# Processing Record 2 of Set 3 | longonjo
# Processing Record 3 of Set 3 | camacupa
# Processing Record 4 of Set 3 | avarua
# Processing Record 5 of Set 3 | puntarenas
# Processing Record 6 of Set 3 | st. john's
# Processing Record 7 of Set 3 | thompson
# Processing Record 8 of Set 3 | prado
# Processing Record 9 of Set 3 | monte plata
# Processing Record 10 of Set 3 | belyy yar
# Processing Record 11 of Set 3 | afaahiti
# Processing Record 12 of Set 3 | west island
# Processing Record 13 of Set 3 | port lincoln
# Processing Record 14 of Set 3 | utrik
# Processing Record 15 of Set 3 | maceio
# Processing Record 16 of Set 3 | la passe
# Processing Record 17 of Set 3 | aral
# Processing Record 18 of Set 3 | el calafate
# Processing Record 19 of Set 3 | galveston
# Processing Record 20 of Set 3 | winslow
# Processing Record 21 of Set 3 | bubaque
# Processing Record 22 of Set 3 | kavaratti
# Processing Record 23 of Set 3 | jiuquan
# Processing Record 24 of Set 3 | ta`u
# Processing Record 25 of Set 3 | chonchi
# Processing Record 26 of Set 3 | polyarnyy
# Processing Record 27 of Set 3 | columbia falls
# Processing Record 28 of Set 3 | pizarro
# Processing Record 29 of Set 3 | iskateley
# Processing Record 30 of Set 3 | portland
# Processing Record 31 of Set 3 | yeppoon
# Processing Record 32 of Set 3 | island harbour
# Processing Record 33 of Set 3 | crane
# Processing Record 34 of Set 3 | stanley
# Processing Record 35 of Set 3 | tura
# Processing Record 36 of Set 3 | mount pearl
# Processing Record 37 of Set 3 | santo antonio
# Processing Record 38 of Set 3 | kouango
# Processing Record 39 of Set 3 | shchyolkino
# Processing Record 40 of Set 3 | talnakh
# Processing Record 41 of Set 3 | hithadhoo
# Processing Record 42 of Set 3 | toliara
# Processing Record 43 of Set 3 | tripoli
# Processing Record 44 of Set 3 | kapa'a
# Processing Record 45 of Set 3 | rockport
# Processing Record 46 of Set 3 | turpan
# Processing Record 47 of Set 3 | vila franca do campo
# Processing Record 48 of Set 3 | nouadhibou
# Processing Record 49 of Set 3 | tokar
# Processing Record 0 of Set 4 | tralee
# Processing Record 1 of Set 4 | okhotsk
# Processing Record 2 of Set 4 | kapsowar
# City not found. Skipping...
# Processing Record 3 of Set 4 | churapcha
# Processing Record 4 of Set 4 | prince rupert
# Processing Record 5 of Set 4 | whitehorse
# Processing Record 6 of Set 4 | fale old settlement
# Processing Record 7 of Set 4 | cable beach
# City not found. Skipping...
# Processing Record 8 of Set 4 | selfoss
# Processing Record 9 of Set 4 | mehran
# Processing Record 10 of Set 4 | malanje
# Processing Record 11 of Set 4 | skovorodino
# Processing Record 12 of Set 4 | valparaiso
# Processing Record 13 of Set 4 | hawaiian paradise park
# Processing Record 14 of Set 4 | ramkola
# Processing Record 15 of Set 4 | san andres
# Processing Record 16 of Set 4 | eirunepe
# Processing Record 17 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 18 of Set 4 | gizo
# Processing Record 19 of Set 4 | klyuchi
# Processing Record 20 of Set 4 | rabaul
# Processing Record 21 of Set 4 | annau
# Processing Record 22 of Set 4 | papatowai
# Processing Record 23 of Set 4 | port mathurin
# Processing Record 24 of Set 4 | murun-kuren
# Processing Record 25 of Set 4 | jamestown
# Processing Record 26 of Set 4 | lukolela
# Processing Record 27 of Set 4 | mwene-ditu
# Processing Record 28 of Set 4 | antsiranana
# Processing Record 29 of Set 4 | georgetown
# Processing Record 30 of Set 4 | eyl
# Processing Record 31 of Set 4 | sinop
# Processing Record 32 of Set 4 | makushino
# Processing Record 33 of Set 4 | tidjikja
# Processing Record 34 of Set 4 | kijang
# Processing Record 35 of Set 4 | tolanaro
# Processing Record 36 of Set 4 | mujiayingzi
# Processing Record 37 of Set 4 | vondrozo
# Processing Record 38 of Set 4 | turtas
# Processing Record 39 of Set 4 | trifesti
# Processing Record 40 of Set 4 | pacific grove
# Processing Record 41 of Set 4 | tazacorte
# Processing Record 42 of Set 4 | kuching
# Processing Record 43 of Set 4 | renfrew
# Processing Record 44 of Set 4 | shizunai-furukawacho
# Processing Record 45 of Set 4 | santa terezinha
# Processing Record 46 of Set 4 | mount gambier
# Processing Record 47 of Set 4 | kovdor
# Processing Record 48 of Set 4 | cherlak
# Processing Record 49 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 0 of Set 5 | taupo
# Processing Record 1 of Set 5 | uturoa
# Processing Record 2 of Set 5 | banff
# Processing Record 3 of Set 5 | payyannur
# Processing Record 4 of Set 5 | boda
# Processing Record 5 of Set 5 | praia da vitoria
# Processing Record 6 of Set 5 | hotan
# Processing Record 7 of Set 5 | luninyets
# Processing Record 8 of Set 5 | atafu village
# Processing Record 9 of Set 5 | antalaha
# Processing Record 10 of Set 5 | argo
# Processing Record 11 of Set 5 | luocheng
# Processing Record 12 of Set 5 | ponta delgada
# Processing Record 13 of Set 5 | pakala
# Processing Record 14 of Set 5 | hornsby bend
# Processing Record 15 of Set 5 | port isabel
# Processing Record 16 of Set 5 | north bend
# Processing Record 17 of Set 5 | piet retief
# Processing Record 18 of Set 5 | inarajan village
# Processing Record 19 of Set 5 | port elizabeth
# Processing Record 20 of Set 5 | buka
# Processing Record 21 of Set 5 | la ronge
# Processing Record 22 of Set 5 | new norfolk
# Processing Record 23 of Set 5 | lihue
# Processing Record 24 of Set 5 | dryden
# Processing Record 25 of Set 5 | male
# Processing Record 26 of Set 5 | padang
# Processing Record 27 of Set 5 | ust'-ilimsk
# Processing Record 28 of Set 5 | khovd
# Processing Record 29 of Set 5 | kharp
# Processing Record 30 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 31 of Set 5 | chibougamau
# Processing Record 32 of Set 5 | bhimunipatnam
# Processing Record 33 of Set 5 | hamilton
# Processing Record 34 of Set 5 | fortuna
# Processing Record 35 of Set 5 | kruisfontein
# Processing Record 36 of Set 5 | carnarvon
# Processing Record 37 of Set 5 | lincheng
# Processing Record 38 of Set 5 | paradip garh
# Processing Record 39 of Set 5 | horenka
# Processing Record 40 of Set 5 | al muwayh
# Processing Record 41 of Set 5 | tuy hoa
# Processing Record 42 of Set 5 | lebu
# Processing Record 43 of Set 5 | jabor
# Processing Record 44 of Set 5 | askoy
# Processing Record 45 of Set 5 | haiku-pauwela
# Processing Record 46 of Set 5 | ust'-uda
# Processing Record 47 of Set 5 | tomatlan
# Processing Record 48 of Set 5 | mananjary
# Processing Record 49 of Set 5 | kapuskasing
# Processing Record 0 of Set 6 | khed
# Processing Record 1 of Set 6 | berbera
# Processing Record 2 of Set 6 | punta arenas
# Processing Record 3 of Set 6 | saratamata
# City not found. Skipping...
# Processing Record 4 of Set 6 | la'ie
# Processing Record 5 of Set 6 | veraval
# Processing Record 6 of Set 6 | severo-yeniseyskiy
# Processing Record 7 of Set 6 | kontagora
# Processing Record 8 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 9 of Set 6 | carry-le-rouet
# Processing Record 10 of Set 6 | kirillov
# Processing Record 11 of Set 6 | pointe-noire
# Processing Record 12 of Set 6 | thunder bay
# Processing Record 13 of Set 6 | wynyard
# Processing Record 14 of Set 6 | yemel'yanovo
# Processing Record 15 of Set 6 | chepo
# Processing Record 16 of Set 6 | ascencion de guarayos
# City not found. Skipping...
# Processing Record 17 of Set 6 | vyazemskiy
# Processing Record 18 of Set 6 | lupane
# Processing Record 19 of Set 6 | rosetta
# Processing Record 20 of Set 6 | quellon
# Processing Record 21 of Set 6 | panshi
# Processing Record 22 of Set 6 | mulayjah
# Processing Record 23 of Set 6 | tha khanon
# Processing Record 24 of Set 6 | vettaikkaranpudur
# Processing Record 25 of Set 6 | gounou gaya
# Processing Record 26 of Set 6 | leava
# Processing Record 27 of Set 6 | papao
# Processing Record 28 of Set 6 | las lomitas
# Processing Record 29 of Set 6 | shihezi
# Processing Record 30 of Set 6 | margaret river
# Processing Record 31 of Set 6 | sal rei
# Processing Record 32 of Set 6 | katsuura
# Processing Record 33 of Set 6 | nikolayevsk-on-amure
# Processing Record 34 of Set 6 | allonnes
# Processing Record 35 of Set 6 | xunchang
# Processing Record 36 of Set 6 | daru
# Processing Record 37 of Set 6 | san patricio
# Processing Record 38 of Set 6 | la gi
# Processing Record 39 of Set 6 | sierra grande
# Processing Record 40 of Set 6 | shahpura
# Processing Record 41 of Set 6 | marshall
# Processing Record 42 of Set 6 | diu
# Processing Record 43 of Set 6 | jurilovca
# Processing Record 44 of Set 6 | thuir
# Processing Record 45 of Set 6 | inirida
# Processing Record 46 of Set 6 | lata
# Processing Record 47 of Set 6 | alta
# Processing Record 48 of Set 6 | vernon
# Processing Record 49 of Set 6 | boldesti-scaeni
# Processing Record 0 of Set 7 | pishva
# Processing Record 1 of Set 7 | kulia village
# City not found. Skipping...
# Processing Record 2 of Set 7 | cabo san lucas
# Processing Record 3 of Set 7 | kristiansund
# Processing Record 4 of Set 7 | vallegrande
# Processing Record 5 of Set 7 | constantia
# Processing Record 6 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 7 | olinda
# Processing Record 8 of Set 7 | mariental
# Processing Record 9 of Set 7 | geraldton
# Processing Record 10 of Set 7 | tchollire
# Processing Record 11 of Set 7 | kingston
# Processing Record 12 of Set 7 | camayenne
# Processing Record 13 of Set 7 | puerto real
# Processing Record 14 of Set 7 | saint-philippe
# Processing Record 15 of Set 7 | chulakkurgan
# Processing Record 16 of Set 7 | hainburg an der donau
# Processing Record 17 of Set 7 | puerto baquerizo moreno
# Processing Record 18 of Set 7 | sechura
# Processing Record 19 of Set 7 | lamu
# Processing Record 20 of Set 7 | sisimiut
# Processing Record 21 of Set 7 | abbeville
# Processing Record 22 of Set 7 | laojunmiao
# Processing Record 23 of Set 7 | new plymouth
# Processing Record 24 of Set 7 | flying fish cove
# Processing Record 25 of Set 7 | bovril
# Processing Record 26 of Set 7 | nanao
# Processing Record 27 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 28 of Set 7 | gebeit
# Processing Record 29 of Set 7 | sitka
# Processing Record 30 of Set 7 | esfarayen
# Processing Record 31 of Set 7 | susuman
# Processing Record 32 of Set 7 | cidreira
# Processing Record 33 of Set 7 | sao vicente
# Processing Record 34 of Set 7 | vanimo
# Processing Record 35 of Set 7 | kone
# Processing Record 36 of Set 7 | manta
# Processing Record 37 of Set 7 | tangalle
# Processing Record 38 of Set 7 | opuwo
# Processing Record 39 of Set 7 | kerikeri
# Processing Record 40 of Set 7 | saint-felicien
# Processing Record 41 of Set 7 | ribadesella
# Processing Record 42 of Set 7 | diawara
# Processing Record 43 of Set 7 | mahajanga
# Processing Record 44 of Set 7 | gillette
# Processing Record 45 of Set 7 | westhill
# Processing Record 46 of Set 7 | vieste
# Processing Record 47 of Set 7 | dunedin
# Processing Record 48 of Set 7 | atar
# Processing Record 49 of Set 7 | sumbawanga
# Processing Record 0 of Set 8 | apolinario saravia
# Processing Record 1 of Set 8 | erenhot
# Processing Record 2 of Set 8 | callao
# Processing Record 3 of Set 8 | hadibu
# Processing Record 4 of Set 8 | gorontalo
# Processing Record 5 of Set 8 | radhanpur
# Processing Record 6 of Set 8 | laiyang
# Processing Record 7 of Set 8 | masterton
# Processing Record 8 of Set 8 | kurumkan
# Processing Record 9 of Set 8 | rukban
# City not found. Skipping...
# Processing Record 10 of Set 8 | prainha
# Processing Record 11 of Set 8 | manokwari
# Processing Record 12 of Set 8 | coahuayana de hidalgo
# Processing Record 13 of Set 8 | natal
# Processing Record 14 of Set 8 | harstad
# Processing Record 15 of Set 8 | noosa heads
# Processing Record 16 of Set 8 | songea
# Processing Record 17 of Set 8 | shimoda
# Processing Record 18 of Set 8 | khanpur
# Processing Record 19 of Set 8 | hasaki
# Processing Record 20 of Set 8 | berezovyy
# Processing Record 21 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 22 of Set 8 | gao
# Processing Record 23 of Set 8 | slavyanka
# Processing Record 24 of Set 8 | plastun
# Processing Record 25 of Set 8 | al jaradiyah
# Processing Record 26 of Set 8 | caconda
# Processing Record 27 of Set 8 | aginskoye
# Processing Record 28 of Set 8 | maridi
# Processing Record 29 of Set 8 | stony plain
# Processing Record 30 of Set 8 | ubari
# Processing Record 31 of Set 8 | bethanie
# Processing Record 32 of Set 8 | sur
# Processing Record 33 of Set 8 | hot springs village
# Processing Record 34 of Set 8 | guerrero negro
# Processing Record 35 of Set 8 | toamasina
# Processing Record 36 of Set 8 | taoudenni
# Processing Record 37 of Set 8 | kuala tungkal
# Processing Record 38 of Set 8 | east london
# Processing Record 39 of Set 8 | constitucion
# Processing Record 40 of Set 8 | victorias
# Processing Record 41 of Set 8 | chokwe
# Processing Record 42 of Set 8 | siping
# Processing Record 43 of Set 8 | berezanskaya
# Processing Record 44 of Set 8 | sarina
# Processing Record 45 of Set 8 | ouesso
# Processing Record 46 of Set 8 | nagqu
# Processing Record 47 of Set 8 | kupang
# Processing Record 48 of Set 8 | labrador city
# Processing Record 49 of Set 8 | knysna
# Processing Record 0 of Set 9 | mejit
# Processing Record 1 of Set 9 | necochea
# Processing Record 2 of Set 9 | cururupu
# Processing Record 3 of Set 9 | rio grande
# Processing Record 4 of Set 9 | ryotsu-minato
# Processing Record 5 of Set 9 | mecitozu
# Processing Record 6 of Set 9 | amanpur
# Processing Record 7 of Set 9 | kalmunai
# Processing Record 8 of Set 9 | laascaanood
# Processing Record 9 of Set 9 | peterhead
# Processing Record 10 of Set 9 | breclav
# Processing Record 11 of Set 9 | yangambi
# Processing Record 12 of Set 9 | parun
# Processing Record 13 of Set 9 | faya-largeau
# Processing Record 14 of Set 9 | mamuju
# Processing Record 15 of Set 9 | darlington
# Processing Record 16 of Set 9 | kasane
# Processing Record 17 of Set 9 | ujae
# Processing Record 18 of Set 9 | olhao
# Processing Record 19 of Set 9 | kill devil hills
# Processing Record 20 of Set 9 | bangor
# Processing Record 21 of Set 9 | tbeng meanchey
# Processing Record 22 of Set 9 | yong peng
# Processing Record 23 of Set 9 | pudozh
# Processing Record 24 of Set 9 | plettenberg bay
# Processing Record 25 of Set 9 | manadhoo
# Processing Record 26 of Set 9 | alice springs
# Processing Record 27 of Set 9 | tadine
# Processing Record 28 of Set 9 | waddan
# Processing Record 29 of Set 9 | bennington
# Processing Record 30 of Set 9 | rongelap
# Processing Record 31 of Set 9 | marrakesh
# Processing Record 32 of Set 9 | touros
# Processing Record 33 of Set 9 | barinas
# Processing Record 34 of Set 9 | bandarbeyla
# Processing Record 35 of Set 9 | dakhla
# Processing Record 36 of Set 9 | santa catalina
# Processing Record 37 of Set 9 | sena madureira
# Processing Record 38 of Set 9 | meulaboh
# Processing Record 39 of Set 9 | aykhal
# Processing Record 40 of Set 9 | fauske
# Processing Record 41 of Set 9 | sos'va
# Processing Record 42 of Set 9 | coquimbo
# Processing Record 43 of Set 9 | sungam-nodongjagu
# Processing Record 44 of Set 9 | babu
# Processing Record 45 of Set 9 | hampton bays
# Processing Record 46 of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 47 of Set 9 | micheweni
# Processing Record 48 of Set 9 | dergachi
# Processing Record 49 of Set 9 | tobelo
# Processing Record 0 of Set 10 | hornsea
# Processing Record 1 of Set 10 | beyneu
# Processing Record 2 of Set 10 | tommot
# Processing Record 3 of Set 10 | urzhar
# Processing Record 4 of Set 10 | port glaud
# City not found. Skipping...
# Processing Record 5 of Set 10 | khorinsk
# Processing Record 6 of Set 10 | ahau
# City not found. Skipping...
# Processing Record 7 of Set 10 | san rafael del sur
# Processing Record 8 of Set 10 | ebon
# Processing Record 9 of Set 10 | shingu
# Processing Record 10 of Set 10 | massawa
# Processing Record 11 of Set 10 | ashland
# Processing Record 12 of Set 10 | fisterra
# Processing Record 13 of Set 10 | palmer
# Processing Record 14 of Set 10 | tuensang
# Processing Record 15 of Set 10 | brumadinho
# Processing Record 16 of Set 10 | kunnamkulam
# Processing Record 17 of Set 10 | weno
# Processing Record 18 of Set 10 | yangshuo
# Processing Record 19 of Set 10 | port alfred
# Processing Record 20 of Set 10 | bontang
# Processing Record 21 of Set 10 | cidade velha
# Processing Record 22 of Set 10 | ad dilam
# Processing Record 23 of Set 10 | hauterive
# Processing Record 24 of Set 10 | nuuk
# Processing Record 25 of Set 10 | san salvador de jujuy
# Processing Record 26 of Set 10 | port blair
# Processing Record 27 of Set 10 | balkanabat
# Processing Record 28 of Set 10 | dumraon
# Processing Record 29 of Set 10 | oliver
# Processing Record 30 of Set 10 | saint-pierre
# Processing Record 31 of Set 10 | ba
# City not found. Skipping...
# Processing Record 32 of Set 10 | namibe
# Processing Record 33 of Set 10 | ridgecrest
# Processing Record 34 of Set 10 | dul'durga
# Processing Record 35 of Set 10 | anadyr
# Processing Record 36 of Set 10 | gaspe
# Processing Record 37 of Set 10 | winston
# Processing Record 38 of Set 10 | margate
# Processing Record 39 of Set 10 | mili
# Processing Record 40 of Set 10 | badagara
# Processing Record 41 of Set 10 | dwarka
# Processing Record 42 of Set 10 | lapeer
# Processing Record 43 of Set 10 | beloyarskiy
# Processing Record 44 of Set 10 | buba
# Processing Record 45 of Set 10 | pekalongan
# Processing Record 46 of Set 10 | kyshtovka
# Processing Record 47 of Set 10 | pandan
# Processing Record 48 of Set 10 | 'ohonua
# City not found. Skipping...
# Processing Record 49 of Set 10 | bandon
# Processing Record 0 of Set 11 | bela
# Processing Record 1 of Set 11 | gornozavodsk
# Processing Record 2 of Set 11 | orenburg
# Processing Record 3 of Set 11 | niquelandia
# Processing Record 4 of Set 11 | rudnya
# Processing Record 5 of Set 11 | nizhneangarsk
# Processing Record 6 of Set 11 | egilsstadir
# Processing Record 7 of Set 11 | kaiapoi
# Processing Record 8 of Set 11 | bamboo flat
# Processing Record 9 of Set 11 | slaton
# Processing Record 10 of Set 11 | jumla
# Processing Record 11 of Set 11 | sadjoavato
# City not found. Skipping...
# Processing Record 12 of Set 11 | santa cruz
# Processing Record 13 of Set 11 | santiago papasquiaro
# City not found. Skipping...
# Processing Record 14 of Set 11 | castillos
# Processing Record 15 of Set 11 | salinopolis
# Processing Record 16 of Set 11 | al ghayzah
# Processing Record 17 of Set 11 | san luis ixcan
# Processing Record 18 of Set 11 | fort bragg
# Processing Record 19 of Set 11 | terrace
# Processing Record 20 of Set 11 | toga village
# City not found. Skipping...
# Processing Record 21 of Set 11 | auki
# Processing Record 22 of Set 11 | monrovia
# Processing Record 23 of Set 11 | tromso
# Processing Record 24 of Set 11 | samamiya
# Processing Record 25 of Set 11 | princeville
# Processing Record 26 of Set 11 | yambol
# Processing Record 27 of Set 11 | la sarre
# Processing Record 28 of Set 11 | issia
# Processing Record 29 of Set 11 | gisborne
# Processing Record 30 of Set 11 | kapchorwa
# Processing Record 31 of Set 11 | puerto aysen
# Processing Record 32 of Set 11 | jos
# Processing Record 33 of Set 11 | safford
# Processing Record 34 of Set 11 | pimentel
# Processing Record 35 of Set 11 | bemaitso
# City not found. Skipping...
# Processing Record 36 of Set 11 | tari
# Processing Record 37 of Set 11 | paita
# Processing Record 38 of Set 11 | yichang
# Processing Record 39 of Set 11 | villa gesell
# Processing Record 40 of Set 11 | port moresby
# Processing Record 41 of Set 11 | la paz
# Processing Record 42 of Set 11 | sibut
# Processing Record 43 of Set 11 | lakatoro
# Processing Record 44 of Set 11 | el bauga
# Processing Record 45 of Set 11 | mansa
# Processing Record 46 of Set 11 | zahedan
# Processing Record 47 of Set 11 | altai
# Processing Record 48 of Set 11 | keskin
# Processing Record 49 of Set 11 | khilok
# Processing Record 0 of Set 12 | merizo village
# Processing Record 1 of Set 12 | pangkalanbuun
# Processing Record 2 of Set 12 | liwale
# Processing Record 3 of Set 12 | ghat
# Processing Record 4 of Set 12 | qamdo
# Processing Record 5 of Set 12 | boguchany
# Processing Record 6 of Set 12 | addiet canna
# Processing Record 7 of Set 12 | itamarandiba
# Processing Record 8 of Set 12 | howrah
# Processing Record 9 of Set 12 | newman
# Processing Record 10 of Set 12 | queenstown
# Processing Record 11 of Set 12 | point pedro
# Processing Record 12 of Set 12 | umatac village
# City not found. Skipping...
# Processing Record 13 of Set 12 | whyalla stuart
# City not found. Skipping...
# Processing Record 14 of Set 12 | horta
# Processing Record 15 of Set 12 | mount isa
# Processing Record 16 of Set 12 | luderitz
# Processing Record 17 of Set 12 | korla
# Processing Record 18 of Set 12 | carutapera
# Processing Record 19 of Set 12 | tranbjerg
# Processing Record 20 of Set 12 | kenai
# Processing Record 21 of Set 12 | shenjiamen
# Processing Record 22 of Set 12 | jakiri
# Processing Record 23 of Set 12 | bani yas city
# City not found. Skipping...
# Processing Record 24 of Set 12 | thaton
# Processing Record 25 of Set 12 | sessa aurunca
# Processing Record 26 of Set 12 | remire-montjoly
# Processing Record 27 of Set 12 | machico
# Processing Record 28 of Set 12 | nabire
# Processing Record 29 of Set 12 | karaj
# Processing Record 30 of Set 12 | westport
# Processing Record 31 of Set 12 | laguna
# Processing Record 32 of Set 12 | caxito
# Processing Record 33 of Set 12 | estreito
# Processing Record 34 of Set 12 | broken hill
# Processing Record 35 of Set 12 | nova sintra
# Processing Record 36 of Set 12 | sao joao da barra
# Processing Record 37 of Set 12 | nishinoomote
# Processing Record 38 of Set 12 | pisco
# Processing Record 39 of Set 12 | corinto
# Processing Record 40 of Set 12 | verrettes
# Processing Record 41 of Set 12 | al jawf
# Processing Record 42 of Set 12 | tymovskoye
# Processing Record 43 of Set 12 | fort mcmurray
# Processing Record 44 of Set 12 | cox's bazar
# Processing Record 45 of Set 12 | maudaha
# Processing Record 46 of Set 12 | ankazoabo
# Processing Record 47 of Set 12 | peace river
# Processing Record 48 of Set 12 | saudarkrokur
# Processing Record 49 of Set 12 | beni
# Processing Record 0 of Set 13 | dingli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          574
# Lat           574
# Lng           574
# Max Temp      574
# Humidity      574
# Cloudiness    574
# Wind Speed    574
# Country       574
# Date          574
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  ulladulla -35.3500  150.4667     11.97        57           0        5.59
# 1     bethel  41.3712  -73.4140     30.92        64         100        2.06
# 2   ust-nera  64.5667  143.2000     14.35        82         100        1.57
# 3  ilulissat  69.2167  -51.1000      7.01        87          75        2.57
# 4  grytviken -54.2811  -36.5092     -7.07        83          23        5.45
#
#   Country        Date
# 0      AU  1688843411
# 1      US  1688843217
# 2      RU  1688843411
# 3      GL  1688843412
# 4      GS  1688843412

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        ulladulla -35.3500  150.4667     11.97        57           0
# 1           bethel  41.3712  -73.4140     30.92        64         100
# 2         ust-nera  64.5667  143.2000     14.35        82         100
# 3        ilulissat  69.2167  -51.1000      7.01        87          75
# 4        grytviken -54.2811  -36.5092     -7.07        83          23
#
#          Wind Speed Country        Date
# City_ID
# 0              5.59      AU  1688843411
# 1              2.06      US  1688843217
# 2              1.57      RU  1688843411
# 3              2.57      GL  1688843412
# 4              5.45      GS  1688843412

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker = "o", edgecolors = "black", alpha = 0.75)


# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Max Latitude vs. Temperature (2023-03-04)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker = "o", edgecolors = "black", alpha = 0.75)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (2023-03-04)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker = "o", edgecolors = "black", alpha = 0.75)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (2023-03-04)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker = "o", edgecolors = "black", alpha = 0.75)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed (2023-03-04)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linearRegressionFunc(xvalue, yvalue):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(xvalue, yvalue)
    regressionValue = xvalue * slope + intercept
    lineEQ = "y = " + str(round(slope, 2)) + "x +" + str(round(intercept, 2))
    
    plt.scatter(xvalue,yvalue, edgecolors = "black", alpha = 0.75, s = 35)
    plt.plot(xvalue,regressionValue,"red")
    
    print(f"The r-value is: {rvalue**2}")
    return lineEQ

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           bethel  41.3712  -73.4140     30.92        64         100
# 2         ust-nera  64.5667  143.2000     14.35        82         100
# 3        ilulissat  69.2167  -51.1000      7.01        87          75
# 6            hakui  36.8833  136.7833     22.96        99         100
# 7           saipan  15.1355  145.7010     28.39       100          20
#
#          Wind Speed Country        Date
# City_ID
# 1              2.06      US  1688843217
# 2              1.57      RU  1688843411
# 3              2.57      GL  1688843412
# 6              3.31      JP  1688843412
# 7              4.92      MP  1688843413

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]


# Display sample data
southern_hemi_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                  ulladulla -35.3500  150.4667     11.97        57
# 4                  grytviken -54.2811  -36.5092     -7.07        83
# 5        san antonio de pale  -1.4014    5.6325     23.09        89
# 11                 adamstown -25.0660 -130.1015     22.76        62
# 13         port-aux-francais -49.3500   70.2167      1.11        81
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 0        5.59      AU  1688843411
# 4                23        5.45      GS  1688843412
# 5               100        5.06      GQ  1688843412
# 11              100        7.02      PN  1688843415
# 13               98        5.35      TF  1688843416

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
northernHemisphere = linearRegressionFunc(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
northernHemisphere

plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(northernHemisphere, (0, -20), fontsize = 15, color = "red")
plt.show()
# Out:
# The r-value is: 0.37725830240367897

# %%
# Linear regression on Southern Hemisphere
southernHemisphere = linearRegressionFunc(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
southernHemisphere

plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(southernHemisphere, (-22, 8), fontsize = 15, color = "red")
plt.show()
# Out:
# The r-value is: 0.7031903986998058

# %% [markdown]
# **Discussion about the linear relationship:** With an r-value of approximately 0.38 we can observe there is a positive correlation with the latitude and maximum temperature of a city. In addition, within the southern hemisphere, there also a positive correlation between latitude and maximum temperature of a city with an r-value of 0.70.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northernHemisphere = linearRegressionFunc(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
northernHemisphere

plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(northernHemisphere, (48, 15), fontsize = 15, color = "red")
plt.show()
# Out:
# The r-value is: 0.0015899775238162712

# %%
# Southern Hemisphere
southernHemisphere = linearRegressionFunc(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
southernHemisphere

plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(southernHemisphere, (-22, 19), fontsize = 15, color = "red")
plt.show()
# Out:
# The r-value is: 0.009401086876684254

# %% [markdown]
# **Discussion about the linear relationship:** The r-values comparing latitude versus humidity for cities in both the northern and southern hemisphere are weakly positive at approximately 0.001 and 0.009 respectively, indicating little to no correlation.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northernHemisphere = linearRegressionFunc(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
northernHemisphere

plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(northernHemisphere, (48, 37), fontsize = 15, color = "red")
plt.show()
# Out:
# The r-value is: 0.0007274150581410431

# %%
# Southern Hemisphere
southernHemisphere = linearRegressionFunc(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
southernHemisphere

plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(southernHemisphere, (-55, 57), fontsize = 15, color = "red")
plt.show()
# Out:
# The r-value is: 2.170284119273404e-05

# %% [markdown]
# **Discussion about the linear relationship:** With an r-value below 0.01 in the northern hemisphere, this indicates no correlation between cloudiness and latitude in a city in the northern hempisphere. On the contrary, with an r-value of 2, there is positive correlation between the cloudiness and latitude of a city in the southern hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northernHemisphere = linearRegressionFunc(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
northernHemisphere

plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(northernHemisphere, (1, 13), fontsize = 15, color = "red")
plt.show()
# Out:
# The r-value is: 0.011351537625599822

# %%
# Southern Hemisphere
southernHemisphere = linearRegressionFunc(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
southernHemisphere

plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(southernHemisphere, (-50, 9.5), fontsize = 15, color = "red")
plt.show()
# Out:
# The r-value is: 0.026194408954373152

# %% [markdown]
# **Discussion about the linear relationship:** As the r-value in the Northern Hempishere is right at 0.01, this is an indication that there is little to no correlation between the wind speed and latitude of a city in the northern hemisphere. As the r-vale for the southern hemisphere is approximately 0.03, there is also very little correlation between the wind speed and latitude of a city in the southern hemisphere.
